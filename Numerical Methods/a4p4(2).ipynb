# %%
from pylab import *
from scipy import special
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binom


def x(n,p):
    list_x=[]
    q= 1-p
    for j in range(n):
        #print ((j-n*p)/np.sqrt(n*p*q))
        list_x+=[(j-n*p)/np.sqrt(n*p*q)]
    return list_x

def y(n,p):
    list_y= []
    q= 1-p
    for j in range(n):
        #print (np.sqrt(n * p * q) * binom.pmf(j, n, p))
        list_y+=[np.sqrt(n * p * q) * binom.pmf(j, n, p)]
    return list_y

def norm_pdf(list_x,n):
    list_gauss=[]
    for i in range(n):
        #print (1/(np.sqrt(2*np.pi)) * np.e**(-x(n,p)[i]**2/2))
        list_gauss+=[1/(np.sqrt(2*np.pi)) * np.e**(-list_x[i]**2/2)]
    return list_gauss

plt.figure(figsize=(12, 5))

plt.subplot(221)
plt.title("n=10, p=0.2")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x(10,0.2),y(10,0.2))
plt.scatter(list_result,norm_pdf(x(10,0.2),10))

plt.subplot(222)
plt.title("n=100, p=0.2")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x(100,0.2),y(100,0.2))
plt.scatter(x(100,0.2),norm_pdf(x(100,0.2),100))

plt.subplot(223)
plt.title("n=10, p=0.5")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x(10,0.5),y(10,0.5))
plt.scatter(x(10,0.5),norm_pdf(x(10,0.5),10))

plt.subplot(224)
plt.title("n=100, p=0.5")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x(100,0.5),y(100,0.5))
plt.scatter(x(100,0.5),norm_pdf(x(100,0.5),100))
show()
