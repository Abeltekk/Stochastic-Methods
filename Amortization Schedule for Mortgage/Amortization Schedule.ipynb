# %%
from pylab import *

pv= 500000
#pv= input("Please enter amount of the loan: ")
n= 20
#n= input("Please enter the term of the mortgage in years: ")
m=12
r= 0.02
#r= input("Please enter the nominal yearly interest rate: ")


c= (pv)*(r/m)*(1-(1+r/m)**(-1*n*m))**-1
x=(1+r/m)
k=arange(1,241)
i= array(k-(n*m))
t=array(x**(i))
pv=(c)*(1-t)/(r/m)
pv= pv.tolist()


for b in range(len(k)):
    if b>0:
        principal=pv[b-1]-pv[b]
        interest=c-principal
        print( b, " |{0:10.3f}|{1:10.3f}|{2:10.3f}|".format(c,interest,principal), pv[b])
# Out:
# 1  |  2529.417|   830.507|  1698.910| 496605.0065106456
# 2  |  2529.417|   827.675|  1701.742| 494903.2648462712
# 3  |  2529.417|   824.839|  1704.578| 493198.6869457893
# 4  |  2529.417|   821.998|  1707.419| 491491.2680821401
# 5  |  2529.417|   819.152|  1710.265| 489781.0035203847
# 6  |  2529.417|   816.302|  1713.115| 488067.88851769315
# 7  |  2529.417|   813.446|  1715.970| 486351.9183233304
# 8  |  2529.417|   810.587|  1718.830| 484633.08817864367
# 9  |  2529.417|   807.722|  1721.695| 482911.3933170492
# 10  |  2529.417|   804.852|  1724.564| 481186.8289640187
# 11  |  2529.417|   801.978|  1727.439| 479459.39033706643
# 12  |  2529.417|   799.099|  1730.318| 477729.07264573604
# 13  |  2529.417|   796.215|  1733.202| 475995.8710915868
# 14  |  2529.417|   793.326|  1736.090| 474259.7808681804
# 15  |  2529.417|   790.433|  1738.984| 472520.7971610685
# 16  |  2529.417|   787.535|  1741.882| 470778.91514777794
# 17  |  2529.417|   784.632|  1744.785| 469034.1299977987
# ...
